# %% [markdown]
# Datasets: https://www.deepfakevfx.com/celebrity-facesets/
#
# LETS TRY ARIANA AND ANNA HATHAWAY AGAIN, we will not resize them as they are already 256x256

# %%
import shutil
import zipfile
import os

import os
from PIL import Image

input_folder = "personA_images"
output_folder = "personA"

os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        img_path = os.path.join(input_folder, filename)
        img = Image.open(img_path)

        width, height = img.size
        square_size = min(width, height)

        img_cropped = img.crop((0, 0, square_size, square_size))

        img_resized = img_cropped.resize((256, 256))

        output_path = os.path.join(output_folder, filename)
        img_resized.save(output_path)

        print(f"Processed: {filename}")

print("All images processed!")
# Out:
# Processed: 00001.jpg
# Processed: 00002.jpg
# Processed: 00003.jpg
# Processed: 00004.jpg
# Processed: 00005.jpg
# Processed: 00006.jpg
# Processed: 00007.jpg
# Processed: 00008.jpg
# Processed: 00009.jpg
# Processed: 00010.jpg
# Processed: 00011.jpg
# Processed: 00012.jpg
# Processed: 00013.jpg
# Processed: 00014.jpg
# Processed: 00015.jpg
# Processed: 00016.jpg
# Processed: 00017.jpg
# Processed: 00019.jpg
# Processed: 00020.jpg
# Processed: 00021.jpg
# Processed: 00022.jpg
# Processed: 00023.jpg
# Processed: 00024.jpg
# Processed: 00025.jpg
# Processed: 00026.jpg
# Processed: 00027.jpg
# Processed: 00028.jpg
# Processed: 00029.jpg
# Processed: 00030.jpg
# Processed: 00031.jpg
# Processed: 00032.jpg
# Processed: 00033.jpg
# Processed: 00034.jpg
# Processed: 00035.jpg
# Processed: 00036.jpg
# Processed: 00037.jpg
# Processed: 00038.jpg
# Processed: 00039.jpg
# Processed: 00040.jpg
# Processed: 00041.jpg
# Processed: 00042.jpg
# Processed: 00043.jpg
# Processed: 00044.jpg
# ...
